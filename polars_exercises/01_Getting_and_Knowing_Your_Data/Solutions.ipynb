# %% [markdown]
# # Polars Exercises 01 — Getting & Knowing Your Data
#
# A raw `orders` dataset just landed in our pipeline (think of a new dataset in Palantir Foundry). Before we build *any* transform on top of it, we have to **get to know the data**: its shape, its columns, its types, and where it is dirty.
#
# *הגיע אלינו dataset גולמי של הזמנות (כמו dataset חדש ב-Foundry). לפני שכותבים טרנספורמציה כלשהי — חייבים קודם להכיר את המידע: כמה שורות, אילו עמודות, אילו טיפוסים, ואיפה המידע “מלוכלך”.*
#
# **Data file:** `data/orders.csv`
#
# ---
#
# > **גרסת פתרונות** — נסו קודם לבד מתוך `Exercises.ipynb`.

# %% [markdown]
# ### 1. Import Polars under the alias `pl`.
#
# *ייבאו את Polars תחת השם `pl`.*

# %%
import polars as pl

# %% [markdown]
# ### 2. Read `data/orders.csv` into a DataFrame called `orders`.
#
# *קראו את הקובץ `data/orders.csv` ל-DataFrame בשם `orders`.*

# %%
orders = pl.read_csv("data/orders.csv")
orders
# Out:
# shape: (1_000, 12)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ order_id   ┆ customer_ ┆ order_dat ┆ region    ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ id        ┆ e         ┆ ---       ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ ORD-000001 ┆ CUST-0171 ┆ 2023-10-2 ┆ Asia      ┆ … ┆ 2.7       ┆ online  ┆ completed ┆ SPRING10  │
# │            ┆           ┆ 5         ┆ Pacific   ┆   ┆           ┆         ┆           ┆           │
# │ ORD-000002 ┆ CUST-0049 ┆ 2023-12-0 ┆ North     ┆ … ┆ 17.88     ┆ online  ┆ completed ┆ BULK      │
# ...

# %% [markdown]
# ### 3. Show the **first 10 rows**.
#
# *הציגו את 10 השורות הראשונות.*

# %%
orders.head(10)
# Out:
# shape: (10, 12)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ order_id   ┆ customer_ ┆ order_dat ┆ region    ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ id        ┆ e         ┆ ---       ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ ORD-000001 ┆ CUST-0171 ┆ 2023-10-2 ┆ Asia      ┆ … ┆ 2.7       ┆ online  ┆ completed ┆ SPRING10  │
# │            ┆           ┆ 5         ┆ Pacific   ┆   ┆           ┆         ┆           ┆           │
# │ ORD-000002 ┆ CUST-0049 ┆ 2023-12-0 ┆ North     ┆ … ┆ 17.88     ┆ online  ┆ completed ┆ BULK      │
# ...

# %% [markdown]
# ### 4. Show the **last 5 rows**.
#
# *הציגו את 5 השורות האחרונות.*

# %%
orders.tail(5)
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ order_id   ┆ customer_ ┆ order_dat ┆ region    ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ id        ┆ e         ┆ ---       ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ ORD-000996 ┆ CUST-0132 ┆ 2023-07-0 ┆ North     ┆ … ┆ 20.78     ┆ online  ┆ cancelled ┆ null      │
# │            ┆           ┆ 6         ┆ America   ┆   ┆           ┆         ┆           ┆           │
# │ ORD-000997 ┆ CUST-0190 ┆ 2023-04-1 ┆ Latin     ┆ … ┆ 9.13      ┆ store   ┆ completed ┆ VIP       │
# ...

# %% [markdown]
# ### 5. How many **rows and columns** does the dataset have?
#
# *כמה שורות ועמודות יש ב-dataset?*

# %%
orders.shape
# Out:
# (1000, 12)

# %% [markdown]
# ### 6. What are the **column names**?
#
# *מהם שמות העמודות?*

# %%
orders.columns
# Out:
# ['order_id',
#  'customer_id',
#  'order_date',
#  'region',
#  'product_sku',
#  'category',
#  'product_name',
#  'quantity',
#  'unit_price',
#  'channel',
#  'status',
#  'discount_code']

# %% [markdown]
# ### 7. What is the **data type of every column**? Notice which type `order_date` got.
#
# *מהו הטיפוס של כל עמודה? שימו לב איזה טיפוס קיבלה `order_date`.*

# %%
orders.schema
# Out:
# Schema([('order_id', String),
#         ('customer_id', String),
#         ('order_date', String),
#         ('region', String),
#         ('product_sku', String),
#         ('category', String),
#         ('product_name', String),
#         ('quantity', Int64),
#         ('unit_price', Float64),
#         ('channel', String),
#         ('status', String),
#         ('discount_code', String)])

# %% [markdown]
# ### 8. Get **summary statistics** for all columns in one call.
#
# *קבלו סטטיסטיקה מסכמת לכל העמודות בקריאה אחת.*

# %%
orders.describe()
# Out:
# shape: (9, 13)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ statistic  ┆ order_id  ┆ customer_ ┆ order_dat ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ ---       ┆ id        ┆ e         ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆           ┆ str       ┆ str       ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ count      ┆ 1000      ┆ 1000      ┆ 1000      ┆ … ┆ 1000.0    ┆ 1000    ┆ 1000      ┆ 427       │
# │ null_count ┆ 0         ┆ 0         ┆ 0         ┆ … ┆ 0.0       ┆ 0       ┆ 0         ┆ 573       │
# │ mean       ┆ null      ┆ null      ┆ null      ┆ … ┆ 8.89282   ┆ null    ┆ null      ┆ null      │
# ...

# %% [markdown]
# ### 9. Use **`glimpse()`** for a transposed, one-line-per-column overview (great for wide datasets).
#
# *השתמשו ב-`glimpse()` לתצוגה הפוכה, שורה לכל עמודה.*

# %%
orders.glimpse()
# Out:
# Rows: 1000
# Columns: 12
# $ order_id      <str> 'ORD-000001', 'ORD-000002', 'ORD-000003', 'ORD-000004', 'ORD-000005', 'ORD-000006', 'ORD-000007', 'ORD-000008', 'ORD-000009', 'ORD-000010'
# $ customer_id   <str> 'CUST-0171', 'CUST-0049', 'CUST-0060', 'CUST-0065', 'CUST-0036', 'CUST-0032', 'CUST-0070', 'CUST-0175', 'CUST-0001', 'CUST-0057'
# $ order_date    <str> '2023-10-25', '2023-12-02', '2023-02-27', '2023-12-26', '2023-05-24', '2023-05-09', '2023-05-10', '2023-08-21', '2023-08-29', '2023-06-22'
# $ region        <str> 'Asia Pacific', 'North America', 'Europe', 'Latin America', 'Asia Pacific', 'Europe', 'North America', 'North America', 'Asia Pacific', 'Asia Pacific'
# $ product_sku   <str> 'PB200', 'SH900', 'BK300', 'SH900', 'PT010', 'BK301', 'PT010', 'BK300', 'PT044', 'PB200'
# $ category      <str> 'pens', 'shirts', 'books', 'shirts', 'posters', 'books', 'posters', 'books', 'posters', 'pens'
# ...

# %% [markdown]
# ### 10. Select **only the `product_name` column**.
#
# *בחרו רק את העמודה `product_name`.*

# %%
orders.select("product_name")
# Out:
# shape: (1_000, 1)
# ┌─────────────────────┐
# │ product_name        │
# │ ---                 │
# │ str                 │
# ╞═════════════════════╡
# │ Gel Pen 12-pack     │
# │ Cotton T-Shirt      │
# │ Paperback Book      │
# │ Cotton T-Shirt      │
# │ Motivational Poster │
# │ …                   │
# │ Cookbook            │
# │ World Map Poster    │
# │ Sticker Sheet       │
# │ Gel Pen 12-pack     │
# │ Paperback Book      │
# └─────────────────────┘

# %% [markdown]
# ### 11. Select the columns `order_id`, `product_name`, `quantity`, `unit_price`.
#
# *בחרו את העמודות `order_id`, `product_name`, `quantity`, `unit_price`.*

# %%
orders.select("order_id", "product_name", "quantity", "unit_price")
# Out:
# shape: (1_000, 4)
# ┌────────────┬─────────────────────┬──────────┬────────────┐
# │ order_id   ┆ product_name        ┆ quantity ┆ unit_price │
# │ ---        ┆ ---                 ┆ ---      ┆ ---        │
# │ str        ┆ str                 ┆ i64      ┆ f64        │
# ╞════════════╪═════════════════════╪══════════╪════════════╡
# │ ORD-000001 ┆ Gel Pen 12-pack     ┆ 15       ┆ 2.7        │
# │ ORD-000002 ┆ Cotton T-Shirt      ┆ 5        ┆ 17.88      │
# │ ORD-000003 ┆ Paperback Book      ┆ 16       ┆ 7.89       │
# │ ORD-000004 ┆ Cotton T-Shirt      ┆ 37       ┆ 17.06      │
# │ ORD-000005 ┆ Motivational Poster ┆ 11       ┆ 7.26       │
# │ …          ┆ …                   ┆ …        ┆ …          │
# │ ORD-000996 ┆ Cookbook            ┆ 2        ┆ 20.78      │
# │ ORD-000997 ┆ World Map Poster    ┆ 37       ┆ 9.13       │
# │ ORD-000998 ┆ Sticker Sheet       ┆ 16       ┆ 1.4        │
# │ ORD-000999 ┆ Gel Pen 12-pack     ┆ -5       ┆ 3.11       │
# ...

# %% [markdown]
# ### 12. How many **distinct products** (`product_sku`) appear in the data?
#
# *כמה מוצרים שונים (`product_sku`) מופיעים במידע?*

# %%
orders["product_sku"].n_unique()
# Out:
# 12

# %% [markdown]
# ### 13. List the **distinct categories**.
#
# *הציגו את הקטגוריות השונות.*

# %%
orders["category"].unique().sort()
# Out:
# shape: (7,)
# Series: 'category' [str]
# [
# 	"books"
# 	"mugs"
# 	"notebooks"
# 	"pens"
# 	"posters"
# 	"shirts"
# 	"stickers"
# ]

# %% [markdown]
# ### 14. How many orders are there **per `status`**? (use `value_counts`)
#
# *כמה הזמנות יש לכל `status`? (השתמשו ב-`value_counts`)*

# %%
orders["status"].value_counts(sort=True)
# Out:
# shape: (4, 2)
# ┌───────────┬───────┐
# │ status    ┆ count │
# │ ---       ┆ ---   │
# │ str       ┆ u32   │
# ╞═══════════╪═══════╡
# │ completed ┆ 820   │
# │ pending   ┆ 83    │
# │ cancelled ┆ 54    │
# │ returned  ┆ 43    │
# └───────────┴───────┘

# %% [markdown]
# ### 15. Which **category** has the most orders?
#
# *לאיזו קטגוריה יש הכי הרבה הזמנות?*

# %%
orders["category"].value_counts(sort=True).head(1)
# Out:
# shape: (1, 2)
# ┌──────────┬───────┐
# │ category ┆ count │
# │ ---      ┆ ---   │
# │ str      ┆ u32   │
# ╞══════════╪═══════╡
# │ posters  ┆ 180   │
# └──────────┴───────┘

# %% [markdown]
# ### 16. What are the **minimum and maximum `quantity`**? (remember: returns are negative)
#
# *מהם הערך המינימלי והמקסימלי של `quantity`? (זכרו: החזרות הן שליליות)*

# %%
orders["quantity"].min(), orders["quantity"].max()
# Out:
# (-5, 39)

# %% [markdown]
# ### 17. What is the **average `unit_price`**, rounded to 2 decimals?
#
# *מהו המחיר הממוצע ליחידה, מעוגל ל-2 ספרות?*

# %%
round(orders["unit_price"].mean(), 2)
# Out:
# 8.89

# %% [markdown]
# ### 18. How many **null (missing) values** does each column have? Which column is dirty?
#
# *כמה ערכים חסרים (null) יש בכל עמודה? איזו עמודה “מלוכלכת”?*

# %%
orders.null_count()
# Out:
# shape: (1, 12)
# ┌──────────┬─────────────┬────────────┬────────┬───┬────────────┬─────────┬────────┬───────────────┐
# │ order_id ┆ customer_id ┆ order_date ┆ region ┆ … ┆ unit_price ┆ channel ┆ status ┆ discount_code │
# │ ---      ┆ ---         ┆ ---        ┆ ---    ┆   ┆ ---        ┆ ---     ┆ ---    ┆ ---           │
# │ u32      ┆ u32         ┆ u32        ┆ u32    ┆   ┆ u32        ┆ u32     ┆ u32    ┆ u32           │
# ╞══════════╪═════════════╪════════════╪════════╪═══╪════════════╪═════════╪════════╪═══════════════╡
# │ 0        ┆ 0           ┆ 0          ┆ 0      ┆ … ┆ 0          ┆ 0       ┆ 0      ┆ 573           │
# └──────────┴─────────────┴────────────┴────────┴───┴────────────┴─────────┴────────┴───────────────┘

# %% [markdown]
# ### 19. Take a **random sample of 5 rows** (use `seed=0` so it is reproducible).
#
# *קחו מדגם אקראי של 5 שורות (השתמשו ב-`seed=0` כדי שיהיה ניתן לשחזור).*

# %%
orders.sample(5, seed=0)
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ order_id   ┆ customer_ ┆ order_dat ┆ region    ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ id        ┆ e         ┆ ---       ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ ORD-000446 ┆ CUST-0124 ┆ 2023-06-2 ┆ Europe    ┆ … ┆ 10.44     ┆ online  ┆ completed ┆ VIP       │
# │            ┆           ┆ 4         ┆           ┆   ┆           ┆         ┆           ┆           │
# │ ORD-000438 ┆ CUST-0061 ┆ 2023-08-0 ┆ North     ┆ … ┆ 6.65      ┆ store   ┆ completed ┆ null      │
# ...

# %% [markdown]
# ### 20. What is the **estimated in-memory size** of the DataFrame, in MB?
#
# *מהו הגודל המשוער בזיכרון של ה-DataFrame, ב-MB?*

# %%
orders.estimated_size("mb")
# Out:
# 0.09344100952148438

# %% [markdown]
# ### 21. Show the **5 largest orders by `quantity`** (highest quantity first).
#
# *הציגו את 5 ההזמנות הגדולות ביותר לפי `quantity`.*

# %%
orders.sort("quantity", descending=True).head(5)
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ order_id   ┆ customer_ ┆ order_dat ┆ region    ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ id        ┆ e         ┆ ---       ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ ORD-000022 ┆ CUST-0199 ┆ 2023-10-1 ┆ Europe    ┆ … ┆ 16.22     ┆ online  ┆ completed ┆ null      │
# │            ┆           ┆ 5         ┆           ┆   ┆           ┆         ┆           ┆           │
# │ ORD-000103 ┆ CUST-0046 ┆ 2023-04-2 ┆ Latin     ┆ … ┆ 20.89     ┆ store   ┆ completed ┆ null      │
# ...

# %% [markdown]
# ### 22. Select rows **10 through 14** (a 5-row slice) using `slice`.
#
# *בחרו את השורות 10 עד 14 (חיתוך של 5 שורות) באמצעות `slice`.*

# %%
orders.slice(10, 5)
# Out:
# shape: (5, 12)
# ┌────────────┬───────────┬───────────┬───────────┬───┬───────────┬─────────┬───────────┬───────────┐
# │ order_id   ┆ customer_ ┆ order_dat ┆ region    ┆ … ┆ unit_pric ┆ channel ┆ status    ┆ discount_ │
# │ ---        ┆ id        ┆ e         ┆ ---       ┆   ┆ e         ┆ ---     ┆ ---       ┆ code      │
# │ str        ┆ ---       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ ---       │
# │            ┆ str       ┆ str       ┆           ┆   ┆ f64       ┆         ┆           ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═══════════╡
# │ ORD-000011 ┆ CUST-0013 ┆ 2023-01-2 ┆ North     ┆ … ┆ 17.42     ┆ online  ┆ completed ┆ null      │
# │            ┆           ┆ 6         ┆ America   ┆   ┆           ┆         ┆           ┆           │
# │ ORD-000012 ┆ CUST-0113 ┆ 2023-12-2 ┆ North     ┆ … ┆ 2.82      ┆ online  ┆ completed ┆ BULK      │
# ...
